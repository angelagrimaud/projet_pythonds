# %%
import requests
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1 - Importation des données de consommation d'électricité par quart d'heure dans les grandes métropoles françaises de 2022 à 2025

# %%
url = "https://odre.opendatasoft.com/api/explore/v2.1/catalog/datasets/eco2mix-metropoles-tr/records?limit=20&refine=libelle_metropole%3A%22M%C3%A9tropole%20du%20Grand%20Paris%22"
req = requests.get(url)
data0 = req.json()
data1 = pd.json_normalize(data0["results"])
data1
# Out:
#    code_insee_epci         libelle_metropole              nature        date  \
# 0        200054781  Métropole du Grand Paris  Données temps réel  2022-04-13
# 1        200054781  Métropole du Grand Paris  Données temps réel  2022-04-13
# 2        200054781  Métropole du Grand Paris  Données temps réel  2022-04-13
# 3        200054781  Métropole du Grand Paris  Données temps réel  2022-04-13
# 4        200054781  Métropole du Grand Paris  Données temps réel  2022-04-13
# 5        200054781  Métropole du Grand Paris  Données temps réel  2022-04-13
# 6        200054781  Métropole du Grand Paris  Données temps réel  2022-04-13
# 7        200054781  Métropole du Grand Paris  Données temps réel  2022-04-13
# 8        200054781  Métropole du Grand Paris  Données temps réel  2022-04-13
# 9        200054781  Métropole du Grand Paris  Données temps réel  2022-04-13
# 10       200054781  Métropole du Grand Paris  Données temps réel  2022-04-13
# ...
